# %%
import pandas as pd

df = pd.read_csv("MSFT.csv")

df
# Out:
#       Index        date   close
# 0         1  11/15/2024  415.00
# 1         2  11/14/2024  426.89
# 2         3  11/13/2024  425.20
# 3         4  11/12/2024  423.03
# 4         5  11/11/2024  418.01
# ...     ...         ...     ...
# 6031   6032  11/24/2000   34.97
# 6032   6033  11/22/2000   34.13
# 6033   6034  11/21/2000   33.88
# 6034   6035  11/20/2000   33.59
# 6035   6036  11/17/2000   34.53
#
# [6036 rows x 3 columns]

# %%
df = df[['date', 'close']]

df
# Out:
#             date   close
# 0     11/15/2024  415.00
# 1     11/14/2024  426.89
# 2     11/13/2024  425.20
# 3     11/12/2024  423.03
# 4     11/11/2024  418.01
# ...          ...     ...
# 6031  11/24/2000   34.97
# 6032  11/22/2000   34.13
# 6033  11/21/2000   33.88
# 6034  11/20/2000   33.59
# 6035  11/17/2000   34.53
#
# [6036 rows x 2 columns]

# %%
df['date']
# Out:
# 0       11/15/2024
# 1       11/14/2024
# 2       11/13/2024
# 3       11/12/2024
# 4       11/11/2024
#            ...
# 6031    11/24/2000
# 6032    11/22/2000
# 6033    11/21/2000
# 6034    11/20/2000
# 6035    11/17/2000
# Name: date, Length: 6036, dtype: object

# %%
import datetime

def temp(s):
  split = s.split("/")
  month, day, year = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year = year, month = month, day = day)
df['date'] = df['date'].apply(temp)

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# <ipython-input-48-929b89a2456b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].apply(temp)
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#            date   close
# 0    2024-11-15  415.00
# 1    2024-11-14  426.89
# 2    2024-11-13  425.20
# 3    2024-11-12  423.03
# 4    2024-11-11  418.01
# ...         ...     ...
# 6031 2000-11-24   34.97
# 6032 2000-11-22   34.13
# 6033 2000-11-21   33.88
# 6034 2000-11-20   33.59
# 6035 2000-11-17   34.53
#
# [6036 rows x 2 columns]

# %%
df.index = df.pop("date")
df
# Out:
#              close
# date
# 2024-11-15  415.00
# 2024-11-14  426.89
# 2024-11-13  425.20
# 2024-11-12  423.03
# 2024-11-11  418.01
# ...            ...
# 2000-11-24   34.97
# 2000-11-22   34.13
# 2000-11-21   33.88
# 2000-11-20   33.59
# 2000-11-17   34.53
#
# [6036 rows x 1 columns]

# %% [markdown]
# flip it so you get from old to newest

# %%
df = df.sort_values(by='date', ascending=True)
df
# Out:
#              close
# date
# 2000-11-17   34.53
# 2000-11-20   33.59
# 2000-11-21   33.88
# 2000-11-22   34.13
# 2000-11-24   34.97
# ...            ...
# 2024-11-11  418.01
# 2024-11-12  423.03
# 2024-11-13  425.20
# 2024-11-14  426.89
# 2024-11-15  415.00
#
# [6036 rows x 1 columns]

# %% [markdown]
# Until now I downloaded the Microsoft stock history, filtered it for just the date and close value, and changed the date format uding Pandas. Now it's time to use Matlab to plot it.

# %%
import matplotlib.pyplot as plt

plt.plot(df.index,  df['close'])

# %% [markdown]
# Convert to a supervised learning problem as we're using LSTM's

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=15):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25	',
                                '2024-11-15',
                                n=15)
windowed_df
# Out:
#     Target Date  Target-15  Target-14  Target-13  Target-12  Target-11  \
# 0    2021-03-25     226.73     231.60     227.39     233.78     232.42
# 1    2021-03-26     231.60     227.39     233.78     232.42     237.13
# 2    2021-03-29     227.39     233.78     232.42     237.13     235.75
# 3    2021-03-30     233.78     232.42     237.13     235.75     234.81
# 4    2021-03-31     232.42     237.13     235.75     234.81     237.71
# ..          ...        ...        ...        ...        ...        ...
# 914  2024-11-11     418.78     427.51     424.60     424.73     428.15
# 915  2024-11-12     427.51     424.60     424.73     428.15     426.59
# 916  2024-11-13     424.60     424.73     428.15     426.59     431.95
# 917  2024-11-14     424.73     428.15     426.59     431.95     432.53
# 918  2024-11-15     428.15     426.59     431.95     432.53     406.35
#
#      Target-10  Target-9  Target-8  Target-7  Target-6  Target-5  Target-4  \
# 0       237.13    235.75    234.81    237.71    237.04    230.72    230.35
# 1       235.75    234.81    237.71    237.04    230.72    230.35    235.99
# 2       234.81    237.71    237.04    230.72    230.35    235.99    237.58
# 3       237.71    237.04    230.72    230.35    235.99    237.58    235.46
# 4       237.04    230.72    230.35    235.99    237.58    235.46    232.34
# ..         ...       ...       ...       ...       ...       ...       ...
# 914     426.59    431.95    432.53    406.35    410.37    408.46    411.46
# 915     431.95    432.53    406.35    410.37    408.46    411.46    420.18
# 916     432.53    406.35    410.37    408.46    411.46    420.18    425.43
# 917     406.35    410.37    408.46    411.46    420.18    425.43    422.54
# 918     410.37    408.46    411.46    420.18    425.43    422.54    418.01
#
#      Target-3  Target-2  Target-1  Target
# 0      235.99    237.58    235.46  232.34
# 1      237.58    235.46    232.34  236.48
# 2      235.46    232.34    236.48  235.24
# 3      232.34    236.48    235.24  231.85
# 4      236.48    235.24    231.85  235.77
# ..        ...       ...       ...     ...
# 914    420.18    425.43    422.54  418.01
# 915    425.43    422.54    418.01  423.03
# 916    422.54    418.01    423.03  425.20
# 917    418.01    423.03    425.20  426.89
# 918    423.03    425.20    426.89  415.00
#
# [919 rows x 17 columns]

# %% [markdown]
# Now, we have a date and the cost of the stock at target, and we have the price upto 3 days ago as well all stored in one windowed panda. So now we can use the previous 3 days to see how it let upto the target date, and train the model.

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((919,), (919, 15, 1), (919,))

# %% [markdown]
# Split the data into train validation and testing partitions

# %%
q_80 = int(len(dates) * .9) #Train until here
q_90 = int(len(dates) * .95) #validate until here
                            #Test for final 10%

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# Time to train and validate our tensorflow model

# %%
from tensorflow.keras.models import Sequential #Buliding a Sequential model
from tensorflow.keras.optimizers import Adam #Optimizer
from tensorflow.keras import layers

model = Sequential([
    layers.Input((15, 1)),
    layers.LSTM(64),
    layers.Dense(32, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])
model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200)
# Out:
# Epoch 1/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 99152.2969 - mean_absolute_error: 309.5428 - val_loss: 176941.2031 - val_mean_absolute_error: 420.3186
# Epoch 2/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 99202.8750 - mean_absolute_error: 309.4403 - val_loss: 172917.1562 - val_mean_absolute_error: 415.5042
# Epoch 3/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 97040.8906 - mean_absolute_error: 305.8584 - val_loss: 164406.0156 - val_mean_absolute_error: 405.1326
# Epoch 4/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 87281.3828 - mean_absolute_error: 289.5513 - val_loss: 147680.7031 - val_mean_absolute_error: 383.9359
# Epoch 5/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 73916.0312 - mean_absolute_error: 264.7241 - val_loss: 118049.0469 - val_mean_absolute_error: 343.1846
# Epoch 6/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 50065.6445 - mean_absolute_error: 216.1394 - val_loss: 82795.4766 - val_mean_absolute_error: 287.2640
# Epoch 7/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29268.2324 - mean_absolute_error: 160.0743 - val_loss: 48361.0117 - val_mean_absolute_error: 219.2832
# Epoch 8/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12193.4580 - mean_absolute_error: 91.8406 - val_loss: 24370.0488 - val_mean_absolute_error: 155.2311
# Epoch 9/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4631.6548 - mean_absolute_error: 51.5992 - val_loss: 14847.5791 - val_mean_absolute_error: 120.7286
# Epoch 10/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3246.3835 - mean_absolute_error: 44.9143 - val_loss: 12534.6934 - val_mean_absolute_error: 110.7700
# Epoch 11/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3513.7776 - mean_absolute_error: 48.5487 - val_loss: 11995.0664 - val_mean_absolute_error: 108.2957
# Epoch 12/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3006.2019 - mean_absolute_error: 44.6682 - val_loss: 11873.1465 - val_mean_absolute_error: 107.7227
# Epoch 13/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3023.9995 - mean_absolute_error: 44.2975 - val_loss: 12032.3740 - val_mean_absolute_error: 108.5163
# Epoch 14/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2781.2163 - mean_absolute_error: 42.3069 - val_loss: 11421.6318 - val_mean_absolute_error: 105.7505
# Epoch 15/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2261.5042 - mean_absolute_error: 36.6976 - val_loss: 8379.7168 - val_mean_absolute_error: 90.2038
# Epoch 16/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1465.5217 - mean_absolute_error: 26.7622 - val_loss: 5639.7549 - val_mean_absolute_error: 73.5225
# Epoch 17/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 843.7219 - mean_absolute_error: 17.7627 - val_loss: 3363.7168 - val_mean_absolute_error: 55.9863
# Epoch 18/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 481.1977 - mean_absolute_error: 13.2433 - val_loss: 2070.6543 - val_mean_absolute_error: 42.9825
# Epoch 19/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 278.8463 - mean_absolute_error: 10.4706 - val_loss: 1377.0376 - val_mean_absolute_error: 34.1517
# Epoch 20/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 249.2867 - mean_absolute_error: 9.7302 - val_loss: 923.1367 - val_mean_absolute_error: 26.9479
# Epoch 21/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 147.7564 - mean_absolute_error: 7.8988 - val_loss: 601.6307 - val_mean_absolute_error: 20.2942
# Epoch 22/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 84.6326 - mean_absolute_error: 6.4073 - val_loss: 456.3918 - val_mean_absolute_error: 16.9815
# Epoch 23/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 92.9374 - mean_absolute_error: 6.5070 - val_loss: 328.7852 - val_mean_absolute_error: 13.5890
# Epoch 24/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 80.2108 - mean_absolute_error: 6.1039 - val_loss: 272.1515 - val_mean_absolute_error: 12.1632
# Epoch 25/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 70.6961 - mean_absolute_error: 5.5736 - val_loss: 254.2997 - val_mean_absolute_error: 11.9563
# Epoch 26/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 75.6001 - mean_absolute_error: 6.3664 - val_loss: 202.9082 - val_mean_absolute_error: 10.4719
# Epoch 27/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 45.8382 - mean_absolute_error: 4.8286 - val_loss: 174.1112 - val_mean_absolute_error: 9.8077
# Epoch 28/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 48.4435 - mean_absolute_error: 4.8687 - val_loss: 161.0664 - val_mean_absolute_error: 9.4955
# Epoch 29/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.4912 - mean_absolute_error: 4.7091 - val_loss: 148.9902 - val_mean_absolute_error: 9.2407
# Epoch 30/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 40.8195 - mean_absolute_error: 4.5571 - val_loss: 142.1042 - val_mean_absolute_error: 9.1177
# Epoch 31/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 47.2526 - mean_absolute_error: 4.8914 - val_loss: 133.3854 - val_mean_absolute_error: 8.9147
# Epoch 32/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.4607 - mean_absolute_error: 4.6196 - val_loss: 138.1477 - val_mean_absolute_error: 9.4695
# Epoch 33/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 47.7214 - mean_absolute_error: 4.9679 - val_loss: 125.0584 - val_mean_absolute_error: 8.8445
# Epoch 34/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.4550 - mean_absolute_error: 4.7057 - val_loss: 123.8311 - val_mean_absolute_error: 8.9215
# Epoch 35/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.3320 - mean_absolute_error: 4.5250 - val_loss: 109.2922 - val_mean_absolute_error: 8.1684
# Epoch 36/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.2415 - mean_absolute_error: 5.2561 - val_loss: 105.7471 - val_mean_absolute_error: 8.1724
# Epoch 37/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 47.2788 - mean_absolute_error: 5.2755 - val_loss: 102.6650 - val_mean_absolute_error: 8.0014
# Epoch 38/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 41.7348 - mean_absolute_error: 4.8700 - val_loss: 113.7907 - val_mean_absolute_error: 8.6032
# Epoch 39/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 34.0991 - mean_absolute_error: 4.3306 - val_loss: 133.7267 - val_mean_absolute_error: 9.5026
# Epoch 40/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 45.7618 - mean_absolute_error: 5.0167 - val_loss: 103.5151 - val_mean_absolute_error: 8.2191
# Epoch 41/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 37.9342 - mean_absolute_error: 4.5098 - val_loss: 127.1872 - val_mean_absolute_error: 9.2429
# Epoch 42/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 34.5027 - mean_absolute_error: 4.4524 - val_loss: 92.2324 - val_mean_absolute_error: 7.7682
# Epoch 43/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 39.4830 - mean_absolute_error: 4.8100 - val_loss: 103.3760 - val_mean_absolute_error: 8.2091
# Epoch 44/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 39.5611 - mean_absolute_error: 4.8510 - val_loss: 132.2262 - val_mean_absolute_error: 9.3940
# Epoch 45/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 33.6883 - mean_absolute_error: 4.3658 - val_loss: 147.1299 - val_mean_absolute_error: 9.9266
# Epoch 46/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.6569 - mean_absolute_error: 5.0777 - val_loss: 176.7687 - val_mean_absolute_error: 11.0507
# Epoch 47/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.9339 - mean_absolute_error: 4.6924 - val_loss: 81.6927 - val_mean_absolute_error: 7.2696
# Epoch 48/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 38.3970 - mean_absolute_error: 4.7567 - val_loss: 111.7559 - val_mean_absolute_error: 8.5253
# Epoch 49/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.0674 - mean_absolute_error: 4.8696 - val_loss: 83.1262 - val_mean_absolute_error: 7.3820
# Epoch 50/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.3708 - mean_absolute_error: 4.8656 - val_loss: 104.2929 - val_mean_absolute_error: 8.1668
# Epoch 51/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.2665 - mean_absolute_error: 4.7535 - val_loss: 86.0231 - val_mean_absolute_error: 7.4850
# Epoch 52/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.0022 - mean_absolute_error: 4.4848 - val_loss: 77.2870 - val_mean_absolute_error: 7.0804
# Epoch 53/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.5131 - mean_absolute_error: 4.6884 - val_loss: 71.7508 - val_mean_absolute_error: 6.6977
# Epoch 54/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.4538 - mean_absolute_error: 4.5015 - val_loss: 115.1096 - val_mean_absolute_error: 8.5898
# Epoch 55/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.4178 - mean_absolute_error: 4.5291 - val_loss: 78.7494 - val_mean_absolute_error: 6.9889
# Epoch 56/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.4175 - mean_absolute_error: 4.4748 - val_loss: 89.6426 - val_mean_absolute_error: 7.5681
# Epoch 57/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.4816 - mean_absolute_error: 4.6324 - val_loss: 88.0189 - val_mean_absolute_error: 7.5007
# Epoch 58/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.7814 - mean_absolute_error: 4.2833 - val_loss: 124.3292 - val_mean_absolute_error: 8.8749
# Epoch 59/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.7294 - mean_absolute_error: 4.3132 - val_loss: 106.1646 - val_mean_absolute_error: 8.1390
# Epoch 60/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.3149 - mean_absolute_error: 4.5879 - val_loss: 77.3944 - val_mean_absolute_error: 6.9754
# Epoch 61/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.4748 - mean_absolute_error: 4.3797 - val_loss: 94.1516 - val_mean_absolute_error: 7.6901
# Epoch 62/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.5817 - mean_absolute_error: 4.9082 - val_loss: 109.7248 - val_mean_absolute_error: 8.2534
# Epoch 63/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.3247 - mean_absolute_error: 4.4220 - val_loss: 77.5178 - val_mean_absolute_error: 6.6837
# Epoch 64/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.0161 - mean_absolute_error: 4.4761 - val_loss: 71.7998 - val_mean_absolute_error: 6.7213
# Epoch 65/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.2797 - mean_absolute_error: 4.5988 - val_loss: 77.2650 - val_mean_absolute_error: 7.0222
# Epoch 66/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 39.6553 - mean_absolute_error: 4.8771 - val_loss: 63.9943 - val_mean_absolute_error: 6.3615
# Epoch 67/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.1038 - mean_absolute_error: 4.4702 - val_loss: 73.4977 - val_mean_absolute_error: 6.7831
# Epoch 68/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.2608 - mean_absolute_error: 4.2552 - val_loss: 58.7255 - val_mean_absolute_error: 6.0310
# Epoch 69/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.5741 - mean_absolute_error: 4.2723 - val_loss: 159.3659 - val_mean_absolute_error: 10.0365
# Epoch 70/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.5838 - mean_absolute_error: 4.8082 - val_loss: 82.1251 - val_mean_absolute_error: 7.0693
# Epoch 71/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.3392 - mean_absolute_error: 4.7294 - val_loss: 111.6598 - val_mean_absolute_error: 8.2938
# Epoch 72/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 40.6749 - mean_absolute_error: 4.9492 - val_loss: 172.8488 - val_mean_absolute_error: 10.6581
# Epoch 73/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 50.4298 - mean_absolute_error: 5.6518 - val_loss: 176.8825 - val_mean_absolute_error: 11.1998
# Epoch 74/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 57.1994 - mean_absolute_error: 5.9606 - val_loss: 68.1068 - val_mean_absolute_error: 6.4817
# Epoch 75/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.9893 - mean_absolute_error: 4.3363 - val_loss: 60.8632 - val_mean_absolute_error: 6.1119
# Epoch 76/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.6915 - mean_absolute_error: 4.3521 - val_loss: 66.1905 - val_mean_absolute_error: 6.3767
# Epoch 77/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.2271 - mean_absolute_error: 4.2770 - val_loss: 140.9422 - val_mean_absolute_error: 9.3582
# Epoch 78/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.4157 - mean_absolute_error: 4.2901 - val_loss: 90.0523 - val_mean_absolute_error: 7.3984
# Epoch 79/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.1177 - mean_absolute_error: 4.3797 - val_loss: 68.5526 - val_mean_absolute_error: 6.4173
# Epoch 80/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.7753 - mean_absolute_error: 4.4984 - val_loss: 66.8238 - val_mean_absolute_error: 6.3184
# Epoch 81/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.4940 - mean_absolute_error: 4.4928 - val_loss: 149.4425 - val_mean_absolute_error: 9.8223
# Epoch 82/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.1048 - mean_absolute_error: 4.3530 - val_loss: 59.6539 - val_mean_absolute_error: 6.0318
# Epoch 83/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 38.1208 - mean_absolute_error: 4.8987 - val_loss: 89.0733 - val_mean_absolute_error: 7.3621
# Epoch 84/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.7661 - mean_absolute_error: 4.4318 - val_loss: 67.4361 - val_mean_absolute_error: 6.3528
# Epoch 85/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.6818 - mean_absolute_error: 3.9500 - val_loss: 135.1390 - val_mean_absolute_error: 9.2289
# Epoch 86/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.8170 - mean_absolute_error: 4.2733 - val_loss: 72.9029 - val_mean_absolute_error: 6.6156
# Epoch 87/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.4675 - mean_absolute_error: 4.0575 - val_loss: 126.0134 - val_mean_absolute_error: 8.9044
# Epoch 88/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.1550 - mean_absolute_error: 4.5989 - val_loss: 63.2677 - val_mean_absolute_error: 6.1202
# Epoch 89/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.3267 - mean_absolute_error: 4.3441 - val_loss: 72.6180 - val_mean_absolute_error: 6.5949
# Epoch 90/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30.8132 - mean_absolute_error: 4.3110 - val_loss: 65.9393 - val_mean_absolute_error: 6.2470
# Epoch 91/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.1088 - mean_absolute_error: 4.8263 - val_loss: 80.9032 - val_mean_absolute_error: 6.9880
# Epoch 92/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.3021 - mean_absolute_error: 4.3368 - val_loss: 57.2786 - val_mean_absolute_error: 6.0881
# Epoch 93/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 36.0988 - mean_absolute_error: 4.7365 - val_loss: 91.1183 - val_mean_absolute_error: 7.4552
# Epoch 94/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 33.4790 - mean_absolute_error: 4.4618 - val_loss: 133.9365 - val_mean_absolute_error: 9.2383
# Epoch 95/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.3393 - mean_absolute_error: 4.4865 - val_loss: 98.0301 - val_mean_absolute_error: 7.7966
# Epoch 96/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.0975 - mean_absolute_error: 4.3203 - val_loss: 53.1109 - val_mean_absolute_error: 5.6169
# Epoch 97/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.8803 - mean_absolute_error: 4.3491 - val_loss: 67.5499 - val_mean_absolute_error: 6.3015
# Epoch 98/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.6191 - mean_absolute_error: 4.2743 - val_loss: 168.4455 - val_mean_absolute_error: 10.6271
# Epoch 99/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.5562 - mean_absolute_error: 4.4446 - val_loss: 102.7963 - val_mean_absolute_error: 8.0095
# Epoch 100/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.2027 - mean_absolute_error: 4.0979 - val_loss: 59.3443 - val_mean_absolute_error: 5.8762
# Epoch 101/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.3051 - mean_absolute_error: 4.4446 - val_loss: 57.6814 - val_mean_absolute_error: 5.8090
# Epoch 102/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.4217 - mean_absolute_error: 4.1086 - val_loss: 51.3075 - val_mean_absolute_error: 5.5501
# Epoch 103/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.8158 - mean_absolute_error: 4.0812 - val_loss: 151.4861 - val_mean_absolute_error: 9.9315
# Epoch 104/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.1402 - mean_absolute_error: 4.0599 - val_loss: 72.9932 - val_mean_absolute_error: 6.6053
# Epoch 105/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.3161 - mean_absolute_error: 4.1527 - val_loss: 128.6492 - val_mean_absolute_error: 9.1104
# Epoch 106/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.0230 - mean_absolute_error: 4.1705 - val_loss: 73.5325 - val_mean_absolute_error: 6.6388
# Epoch 107/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.7499 - mean_absolute_error: 4.0563 - val_loss: 65.5989 - val_mean_absolute_error: 6.2231
# Epoch 108/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.6317 - mean_absolute_error: 4.4683 - val_loss: 129.1490 - val_mean_absolute_error: 9.1318
# Epoch 109/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.7761 - mean_absolute_error: 4.1000 - val_loss: 110.2899 - val_mean_absolute_error: 8.4392
# Epoch 110/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.1944 - mean_absolute_error: 4.5204 - val_loss: 122.1822 - val_mean_absolute_error: 8.8516
# Epoch 111/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8268 - mean_absolute_error: 4.2193 - val_loss: 116.5640 - val_mean_absolute_error: 8.5253
# Epoch 112/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.2110 - mean_absolute_error: 4.0677 - val_loss: 143.6521 - val_mean_absolute_error: 9.6936
# Epoch 113/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.7749 - mean_absolute_error: 4.4633 - val_loss: 114.0358 - val_mean_absolute_error: 8.5125
# Epoch 114/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.0406 - mean_absolute_error: 4.3565 - val_loss: 50.7202 - val_mean_absolute_error: 5.4317
# Epoch 115/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.8110 - mean_absolute_error: 4.5000 - val_loss: 62.0334 - val_mean_absolute_error: 6.5296
# Epoch 116/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.2232 - mean_absolute_error: 4.4101 - val_loss: 100.7708 - val_mean_absolute_error: 8.1431
# Epoch 117/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.0592 - mean_absolute_error: 4.9327 - val_loss: 45.2194 - val_mean_absolute_error: 5.1092
# Epoch 118/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.5335 - mean_absolute_error: 5.0248 - val_loss: 206.7234 - val_mean_absolute_error: 12.5105
# Epoch 119/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.1227 - mean_absolute_error: 4.7365 - val_loss: 87.1853 - val_mean_absolute_error: 7.3403
# Epoch 120/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.8326 - mean_absolute_error: 4.1180 - val_loss: 154.0018 - val_mean_absolute_error: 9.8991
# Epoch 121/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.2094 - mean_absolute_error: 4.1316 - val_loss: 71.8834 - val_mean_absolute_error: 6.5907
# Epoch 122/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.3444 - mean_absolute_error: 4.4523 - val_loss: 56.9198 - val_mean_absolute_error: 5.6979
# Epoch 123/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.6274 - mean_absolute_error: 3.9673 - val_loss: 115.3153 - val_mean_absolute_error: 8.5464
# Epoch 124/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.0265 - mean_absolute_error: 4.2596 - val_loss: 114.5968 - val_mean_absolute_error: 8.4187
# Epoch 125/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.8056 - mean_absolute_error: 4.2153 - val_loss: 51.9994 - val_mean_absolute_error: 5.5263
# Epoch 126/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.6164 - mean_absolute_error: 4.1857 - val_loss: 42.3635 - val_mean_absolute_error: 5.0925
# Epoch 127/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.7877 - mean_absolute_error: 4.2245 - val_loss: 43.1266 - val_mean_absolute_error: 4.9515
# Epoch 128/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.8707 - mean_absolute_error: 3.9527 - val_loss: 59.7104 - val_mean_absolute_error: 5.8936
# Epoch 129/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.0046 - mean_absolute_error: 4.3199 - val_loss: 57.1954 - val_mean_absolute_error: 5.7528
# Epoch 130/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.6109 - mean_absolute_error: 4.4168 - val_loss: 75.9347 - val_mean_absolute_error: 6.7635
# Epoch 131/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.5936 - mean_absolute_error: 4.8823 - val_loss: 73.8975 - val_mean_absolute_error: 6.6521
# Epoch 132/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.4630 - mean_absolute_error: 4.6838 - val_loss: 87.9919 - val_mean_absolute_error: 7.4488
# Epoch 133/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.6218 - mean_absolute_error: 4.4236 - val_loss: 49.4400 - val_mean_absolute_error: 5.8204
# Epoch 134/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.5202 - mean_absolute_error: 4.5781 - val_loss: 89.5766 - val_mean_absolute_error: 7.5456
# Epoch 135/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.0378 - mean_absolute_error: 4.4199 - val_loss: 46.0779 - val_mean_absolute_error: 5.0348
# Epoch 136/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.1773 - mean_absolute_error: 4.0627 - val_loss: 52.4940 - val_mean_absolute_error: 5.4185
# Epoch 137/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.8999 - mean_absolute_error: 4.2434 - val_loss: 48.4348 - val_mean_absolute_error: 5.1699
# Epoch 138/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.5352 - mean_absolute_error: 4.1277 - val_loss: 45.4822 - val_mean_absolute_error: 4.9847
# Epoch 139/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.1380 - mean_absolute_error: 4.6631 - val_loss: 69.5629 - val_mean_absolute_error: 6.4705
# Epoch 140/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 40.6866 - mean_absolute_error: 5.0407 - val_loss: 64.0610 - val_mean_absolute_error: 6.2852
# Epoch 141/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 29.1087 - mean_absolute_error: 4.2333 - val_loss: 96.2365 - val_mean_absolute_error: 7.6613
# Epoch 142/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.1410 - mean_absolute_error: 4.1082 - val_loss: 193.5268 - val_mean_absolute_error: 11.4116
# Epoch 143/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.9983 - mean_absolute_error: 4.3902 - val_loss: 171.4174 - val_mean_absolute_error: 11.3667
# Epoch 144/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 35.4608 - mean_absolute_error: 4.6943 - val_loss: 61.5585 - val_mean_absolute_error: 6.0077
# Epoch 145/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.5255 - mean_absolute_error: 4.6268 - val_loss: 46.8206 - val_mean_absolute_error: 5.0354
# Epoch 146/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.6699 - mean_absolute_error: 3.7974 - val_loss: 90.6007 - val_mean_absolute_error: 7.6211
# Epoch 147/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 32.6066 - mean_absolute_error: 4.4832 - val_loss: 77.9314 - val_mean_absolute_error: 6.8300
# Epoch 148/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.3193 - mean_absolute_error: 4.1691 - val_loss: 132.7494 - val_mean_absolute_error: 8.9044
# Epoch 149/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.4224 - mean_absolute_error: 4.0509 - val_loss: 53.4366 - val_mean_absolute_error: 5.7755
# Epoch 150/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.3356 - mean_absolute_error: 4.0772 - val_loss: 76.7967 - val_mean_absolute_error: 6.9196
# Epoch 151/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.6321 - mean_absolute_error: 4.1397 - val_loss: 45.2285 - val_mean_absolute_error: 5.0936
# Epoch 152/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.3660 - mean_absolute_error: 4.3009 - val_loss: 80.8605 - val_mean_absolute_error: 7.0914
# Epoch 153/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.1044 - mean_absolute_error: 4.4945 - val_loss: 61.4681 - val_mean_absolute_error: 6.6102
# Epoch 154/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.9808 - mean_absolute_error: 4.6926 - val_loss: 60.2934 - val_mean_absolute_error: 6.3689
# Epoch 155/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 42.3134 - mean_absolute_error: 5.2259 - val_loss: 40.7440 - val_mean_absolute_error: 5.1099
# Epoch 156/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.7211 - mean_absolute_error: 3.9861 - val_loss: 37.4771 - val_mean_absolute_error: 4.7617
# Epoch 157/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.1628 - mean_absolute_error: 4.2091 - val_loss: 66.4813 - val_mean_absolute_error: 6.2291
# Epoch 158/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.6147 - mean_absolute_error: 4.1499 - val_loss: 37.6807 - val_mean_absolute_error: 4.7023
# Epoch 159/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.2440 - mean_absolute_error: 4.3473 - val_loss: 63.8297 - val_mean_absolute_error: 6.0718
# Epoch 160/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.8958 - mean_absolute_error: 4.4300 - val_loss: 76.4706 - val_mean_absolute_error: 6.8504
# Epoch 161/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.6884 - mean_absolute_error: 4.3588 - val_loss: 56.4561 - val_mean_absolute_error: 5.6030
# Epoch 162/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.2770 - mean_absolute_error: 4.4902 - val_loss: 56.2155 - val_mean_absolute_error: 5.5818
# Epoch 163/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.1673 - mean_absolute_error: 4.7611 - val_loss: 39.5618 - val_mean_absolute_error: 5.0092
# Epoch 164/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.4412 - mean_absolute_error: 4.5380 - val_loss: 60.1926 - val_mean_absolute_error: 6.6069
# Epoch 165/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 47.2245 - mean_absolute_error: 5.4568 - val_loss: 39.7716 - val_mean_absolute_error: 4.6414
# Epoch 166/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.4673 - mean_absolute_error: 3.8322 - val_loss: 42.0782 - val_mean_absolute_error: 4.8039
# Epoch 167/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.2472 - mean_absolute_error: 4.0177 - val_loss: 40.2977 - val_mean_absolute_error: 4.7456
# Epoch 168/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.9304 - mean_absolute_error: 4.2927 - val_loss: 64.7133 - val_mean_absolute_error: 6.1254
# Epoch 169/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.8649 - mean_absolute_error: 4.1631 - val_loss: 50.4346 - val_mean_absolute_error: 5.2194
# Epoch 170/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.7030 - mean_absolute_error: 3.9471 - val_loss: 40.6424 - val_mean_absolute_error: 4.8150
# Epoch 171/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.0771 - mean_absolute_error: 4.2111 - val_loss: 37.1082 - val_mean_absolute_error: 4.8161
# Epoch 172/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.5512 - mean_absolute_error: 4.1301 - val_loss: 44.5685 - val_mean_absolute_error: 4.8391
# Epoch 173/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.2841 - mean_absolute_error: 4.2210 - val_loss: 85.9119 - val_mean_absolute_error: 7.4258
# Epoch 174/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.2856 - mean_absolute_error: 4.1252 - val_loss: 49.0151 - val_mean_absolute_error: 5.1129
# Epoch 175/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.5316 - mean_absolute_error: 4.3770 - val_loss: 38.4150 - val_mean_absolute_error: 4.7223
# Epoch 176/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.5963 - mean_absolute_error: 4.4502 - val_loss: 42.2493 - val_mean_absolute_error: 4.7313
# Epoch 177/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.6659 - mean_absolute_error: 4.1678 - val_loss: 38.5525 - val_mean_absolute_error: 5.0012
# Epoch 178/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.6197 - mean_absolute_error: 4.0424 - val_loss: 46.8872 - val_mean_absolute_error: 4.9859
# Epoch 179/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.6347 - mean_absolute_error: 3.9533 - val_loss: 40.4144 - val_mean_absolute_error: 4.7850
# Epoch 180/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.9739 - mean_absolute_error: 4.0021 - val_loss: 37.4890 - val_mean_absolute_error: 4.5924
# Epoch 181/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.4607 - mean_absolute_error: 3.9480 - val_loss: 46.4968 - val_mean_absolute_error: 4.9746
# Epoch 182/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.4362 - mean_absolute_error: 4.0790 - val_loss: 53.9170 - val_mean_absolute_error: 5.4299
# Epoch 183/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.1284 - mean_absolute_error: 4.4550 - val_loss: 57.6088 - val_mean_absolute_error: 5.6725
# Epoch 184/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.5046 - mean_absolute_error: 4.1553 - val_loss: 41.4392 - val_mean_absolute_error: 4.8467
# Epoch 185/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.6143 - mean_absolute_error: 4.3209 - val_loss: 39.9237 - val_mean_absolute_error: 5.0608
# Epoch 186/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.3868 - mean_absolute_error: 4.8273 - val_loss: 45.0589 - val_mean_absolute_error: 5.6147
# Epoch 187/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.5295 - mean_absolute_error: 4.4515 - val_loss: 110.5329 - val_mean_absolute_error: 8.5661
# Epoch 188/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 28.0644 - mean_absolute_error: 4.0899 - val_loss: 91.3566 - val_mean_absolute_error: 7.3139
# Epoch 189/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.5804 - mean_absolute_error: 4.2623 - val_loss: 61.7902 - val_mean_absolute_error: 6.1767
# Epoch 190/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 28.5634 - mean_absolute_error: 4.0924 - val_loss: 40.8991 - val_mean_absolute_error: 4.9125
# Epoch 191/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 33.2072 - mean_absolute_error: 4.5037 - val_loss: 51.2999 - val_mean_absolute_error: 5.7914
# Epoch 192/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32.8481 - mean_absolute_error: 4.2857 - val_loss: 52.7246 - val_mean_absolute_error: 5.5763
# Epoch 193/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.3364 - mean_absolute_error: 4.3531 - val_loss: 46.9498 - val_mean_absolute_error: 5.7746
# Epoch 194/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 35.3789 - mean_absolute_error: 4.6195 - val_loss: 53.6377 - val_mean_absolute_error: 5.8852
# Epoch 195/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 28.0669 - mean_absolute_error: 4.0962 - val_loss: 54.1817 - val_mean_absolute_error: 5.4986
# Epoch 196/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 24.2188 - mean_absolute_error: 3.7465 - val_loss: 70.1245 - val_mean_absolute_error: 6.3959
# Epoch 197/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 29.4809 - mean_absolute_error: 4.1424 - val_loss: 46.6905 - val_mean_absolute_error: 5.1861
# Epoch 198/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.4249 - mean_absolute_error: 4.2288 - val_loss: 45.9547 - val_mean_absolute_error: 4.9061
# Epoch 199/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.0902 - mean_absolute_error: 4.0395 - val_loss: 39.6940 - val_mean_absolute_error: 5.1907
# Epoch 200/200
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.9766 - mean_absolute_error: 4.1398 - val_loss: 38.2569 - val_mean_absolute_error: 4.7242

# %%
train_predictions = model.predict(X_train).flatten()
plt. plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
val_predictions = model.predict(X_val).flatten()
plt. plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# LSTM Can't extrapolate data well. (Extrapolate means predict data out of the time zone or outside your field of knowledge, create prediction) The LSTM Is only good at data it is familiar with.

# %%
import datetime
import matplotlib.dates as mdates

def predict_next_month(model, last_n_days, num_days=15):
    """
    Predicts the stock price for the next month, day by day.

    Args:
        model: The trained LSTM model.
        last_n_days: The last 'n' days of data used for the initial prediction.
        num_days: The number of days to predict (default: 30).

    Returns:
        A tuple containing the predicted dates and prices.
    """

    predictions = []
    current_date = dates_test[-1] + datetime.timedelta(days=1)  # Start from the day after the last test date
    input_data = last_n_days.reshape(1, last_n_days.shape[0], 1)  # Reshape for model input

    for _ in range(num_days):
        prediction = model.predict(input_data)[0, 0]  # Predict next day's price
        predictions.append(prediction)

        # Update input data with the prediction for the next iteration
        input_data = np.roll(input_data, -1, axis=1)  # Shift data one day back
        input_data[0, -1, 0] = prediction  # Replace last value with prediction

        current_date += datetime.timedelta(days=1)

    predicted_dates = [dates_test[-1] + datetime.timedelta(days=i + 1) for i in range(num_days)]

    return predicted_dates, predictions

# Get the last 15 days of data from the test set
last_15_days = X_test[-1, :, 0]

# Predict for the next 30 days
predicted_dates, predicted_prices = predict_next_month(model, last_15_days)

# Plot the predicted data
plt.plot(predicted_dates, predicted_prices, label='Predicted')
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d'))
plt.ylabel('Stock Price')
plt.title('Next 15 days Prediction')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
