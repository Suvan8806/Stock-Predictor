# %%
import pandas as pd

df = pd.read_csv("GOOG.csv")

df
# Out:
#       Index        date   close
# 0         1  11/18/2024  176.00
# 1         2  11/15/2024  173.89
# 2         3  11/14/2024  177.35
# 3         4  11/13/2024  180.49
# 4         5  11/12/2024  183.32
# ...     ...         ...     ...
# 4776   4777  11/25/2005   10.68
# 4777   4778  11/23/2005   10.53
# 4778   4779  11/22/2005   10.37
# 4779   4780  11/21/2005   10.20
# 4780   4781  11/18/2005    9.97
#
# [4781 rows x 3 columns]

# %%
df = df[['date', 'close']]

df
# Out:
#             date   close
# 0     11/18/2024  176.00
# 1     11/15/2024  173.89
# 2     11/14/2024  177.35
# 3     11/13/2024  180.49
# 4     11/12/2024  183.32
# ...          ...     ...
# 4776  11/25/2005   10.68
# 4777  11/23/2005   10.53
# 4778  11/22/2005   10.37
# 4779  11/21/2005   10.20
# 4780  11/18/2005    9.97
#
# [4781 rows x 2 columns]

# %%
df['date']
# Out:
# 0       11/18/2024
# 1       11/15/2024
# 2       11/14/2024
# 3       11/13/2024
# 4       11/12/2024
#            ...
# 4776    11/25/2005
# 4777    11/23/2005
# 4778    11/22/2005
# 4779    11/21/2005
# 4780    11/18/2005
# Name: date, Length: 4781, dtype: object

# %%
import datetime

def temp(s):
  split = s.split("/")
  month, day, year = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year = year, month = month, day = day)
df['date'] = df['date'].apply(temp)

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# <ipython-input-4-929b89a2456b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date'] = df['date'].apply(temp)
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#            date   close
# 0    2024-11-18  176.00
# 1    2024-11-15  173.89
# 2    2024-11-14  177.35
# 3    2024-11-13  180.49
# 4    2024-11-12  183.32
# ...         ...     ...
# 4776 2005-11-25   10.68
# 4777 2005-11-23   10.53
# 4778 2005-11-22   10.37
# 4779 2005-11-21   10.20
# 4780 2005-11-18    9.97
#
# [4781 rows x 2 columns]

# %%
df.index = df.pop("date")
df
# Out:
#              close
# date
# 2024-11-18  176.00
# 2024-11-15  173.89
# 2024-11-14  177.35
# 2024-11-13  180.49
# 2024-11-12  183.32
# ...            ...
# 2005-11-25   10.68
# 2005-11-23   10.53
# 2005-11-22   10.37
# 2005-11-21   10.20
# 2005-11-18    9.97
#
# [4781 rows x 1 columns]

# %% [markdown]
# flip it so you get from old to newest

# %%
df = df.sort_values(by='date', ascending=True)
df
# Out:
#              close
# date
# 2005-11-18    9.97
# 2005-11-21   10.20
# 2005-11-22   10.37
# 2005-11-23   10.53
# 2005-11-25   10.68
# ...            ...
# 2024-11-12  183.32
# 2024-11-13  180.49
# 2024-11-14  177.35
# 2024-11-15  173.89
# 2024-11-18  176.00
#
# [4781 rows x 1 columns]

# %% [markdown]
# Until now I downloaded the Microsoft stock history, filtered it for just the date and close value, and changed the date format uding Pandas. Now it's time to use Matlab to plot it.

# %%
import matplotlib.pyplot as plt

plt.plot(df.index,  df['close'])

# %% [markdown]
# Convert to a supervised learning problem as we're using LSTM's

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=30):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2020-03-25	',
                                '2024-11-15',
                                n=30)
windowed_df
# Out:
#      Target Date  Target-30  Target-29  Target-28  Target-27  Target-26  \
# 0     2020-03-25      75.44      75.91      75.73      76.04      75.98
# 1     2020-03-26      75.91      75.73      76.04      75.98      76.33
# 2     2020-03-27      75.73      76.04      75.98      76.33      75.91
# 3     2020-03-30      76.04      75.98      76.33      75.91      74.26
# 4     2020-03-31      75.98      76.33      75.91      74.26      71.08
# ...          ...        ...        ...        ...        ...        ...
# 1166  2024-11-11     167.19     168.42     167.31     167.21     168.56
# 1167  2024-11-12     168.42     167.31     167.21     168.56     164.39
# 1168  2024-11-13     167.31     167.21     168.56     164.39     165.70
# 1169  2024-11-14     167.21     168.56     164.39     165.70     163.06
# 1170  2024-11-15     168.56     164.39     165.70     163.06     163.18
#
#       Target-25  Target-24  Target-23  Target-22  ...  Target-9  Target-8  \
# 0         76.33      75.91      74.26      71.08  ...     55.75     60.99
# 1         75.91      74.26      71.08      69.42  ...     60.99     54.22
# 2         74.26      71.08      69.42      69.66  ...     54.22     55.99
# 3         71.08      69.42      69.66      65.90  ...     55.99     54.84
# 4         69.42      69.66      65.90      66.97  ...     54.84     55.76
# ...         ...        ...        ...        ...  ...       ...       ...
# 1166     164.39     165.70     163.06     163.18  ...    171.14    176.14
# 1167     165.70     163.06     163.18     164.52  ...    176.14    172.69
# 1168     163.06     163.18     164.52     166.35  ...    172.69    172.65
# 1169     163.18     164.52     166.35     166.90  ...    172.65    170.68
# 1170     164.52     166.35     166.90     166.74  ...    170.68    171.41
#
#       Target-7  Target-6  Target-5  Target-4  Target-3  Target-2  Target-1  \
# 0        54.22     55.99     54.84     55.76     53.62     52.83     56.72
# 1        55.99     54.84     55.76     53.62     52.83     56.72     55.12
# 2        54.84     55.76     53.62     52.83     56.72     55.12     58.09
# 3        55.76     53.62     52.83     56.72     55.12     58.09     55.54
# 4        53.62     52.83     56.72     55.12     58.09     55.54     57.34
# ...        ...       ...       ...       ...       ...       ...       ...
# 1166    172.69    172.65    170.68    171.41    178.33    182.28    179.86
# 1167    172.65    170.68    171.41    178.33    182.28    179.86    181.97
# 1168    170.68    171.41    178.33    182.28    179.86    181.97    183.32
# 1169    171.41    178.33    182.28    179.86    181.97    183.32    180.49
# 1170    178.33    182.28    179.86    181.97    183.32    180.49    177.35
#
#       Target
# 0      55.12
# 1      58.09
# 2      55.54
# 3      57.34
# 4      58.14
# ...      ...
# 1166  181.97
# 1167  183.32
# 1168  180.49
# 1169  177.35
# 1170  173.89
#
# [1171 rows x 32 columns]

# %% [markdown]
# Now, we have a date and the cost of the stock at target, and we have the price upto 3 days ago as well all stored in one windowed panda. So now we can use the previous 3 days to see how it let upto the target date, and train the model.

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((1171,), (1171, 30, 1), (1171,))

# %% [markdown]
# Split the data into train validation and testing partitions

# %%
q_80 = int(len(dates) * .9) #Train until here
q_90 = int(len(dates) * .95) #validate until here
                            #Test for final 10%

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# Time to train and validate our tensorflow model

# %%
from tensorflow.keras.models import Sequential #Buliding a Sequential model
from tensorflow.keras.optimizers import Adam #Optimizer
from tensorflow.keras import layers

model = Sequential([
    layers.Input((30, 1)),
    layers.LSTM(64),
    layers.Dense(32, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])
model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 13583.8896 - mean_absolute_error: 113.5592 - val_loss: 29573.4395 - val_mean_absolute_error: 171.7397
# Epoch 2/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12398.4443 - mean_absolute_error: 108.1476 - val_loss: 24914.2793 - val_mean_absolute_error: 157.5892
# Epoch 3/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7750.5938 - mean_absolute_error: 82.6856 - val_loss: 11042.9072 - val_mean_absolute_error: 104.7035
# Epoch 4/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1615.4077 - mean_absolute_error: 33.7873 - val_loss: 3520.2908 - val_mean_absolute_error: 58.6644
# Epoch 5/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 691.6000 - mean_absolute_error: 22.1090 - val_loss: 3843.1504 - val_mean_absolute_error: 61.3635
# Epoch 6/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 619.1246 - mean_absolute_error: 21.2350 - val_loss: 3149.3218 - val_mean_absolute_error: 55.4576
# Epoch 7/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 254.8608 - mean_absolute_error: 12.5638 - val_loss: 1555.4147 - val_mean_absolute_error: 38.5346
# Epoch 8/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.6337 - mean_absolute_error: 4.7723 - val_loss: 787.5259 - val_mean_absolute_error: 26.7675
# Epoch 9/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.0612 - mean_absolute_error: 2.5155 - val_loss: 491.5795 - val_mean_absolute_error: 20.6119
# Epoch 10/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.1031 - mean_absolute_error: 2.5100 - val_loss: 348.4790 - val_mean_absolute_error: 16.9571
# Epoch 11/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.0821 - mean_absolute_error: 2.2127 - val_loss: 252.0060 - val_mean_absolute_error: 13.9978
# Epoch 12/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.2932 - mean_absolute_error: 2.0788 - val_loss: 183.0583 - val_mean_absolute_error: 11.5134
# Epoch 13/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.1001 - mean_absolute_error: 2.0784 - val_loss: 136.9714 - val_mean_absolute_error: 9.6423
# Epoch 14/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.0390 - mean_absolute_error: 1.8988 - val_loss: 102.1536 - val_mean_absolute_error: 8.1857
# Epoch 15/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0544 - mean_absolute_error: 1.9167 - val_loss: 73.7713 - val_mean_absolute_error: 7.0046
# Epoch 16/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2297 - mean_absolute_error: 1.9879 - val_loss: 61.8041 - val_mean_absolute_error: 6.4628
# Epoch 17/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9563 - mean_absolute_error: 1.9186 - val_loss: 58.3214 - val_mean_absolute_error: 6.1617
# Epoch 18/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4176 - mean_absolute_error: 1.8968 - val_loss: 51.4448 - val_mean_absolute_error: 5.8294
# Epoch 19/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2840 - mean_absolute_error: 1.7130 - val_loss: 47.3316 - val_mean_absolute_error: 5.7036
# Epoch 20/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8621 - mean_absolute_error: 1.9064 - val_loss: 42.3732 - val_mean_absolute_error: 5.3218
# Epoch 21/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6632 - mean_absolute_error: 1.8020 - val_loss: 43.1633 - val_mean_absolute_error: 5.4651
# Epoch 22/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6458 - mean_absolute_error: 1.7673 - val_loss: 39.5430 - val_mean_absolute_error: 5.1589
# Epoch 23/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2985 - mean_absolute_error: 1.6648 - val_loss: 40.2862 - val_mean_absolute_error: 5.2408
# Epoch 24/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6852 - mean_absolute_error: 1.7279 - val_loss: 36.7160 - val_mean_absolute_error: 4.9058
# Epoch 25/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6990 - mean_absolute_error: 1.7501 - val_loss: 39.7529 - val_mean_absolute_error: 5.2430
# Epoch 26/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7422 - mean_absolute_error: 1.7304 - val_loss: 36.1936 - val_mean_absolute_error: 4.9402
# Epoch 27/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6041 - mean_absolute_error: 1.9251 - val_loss: 36.5526 - val_mean_absolute_error: 4.9799
# Epoch 28/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8381 - mean_absolute_error: 1.6083 - val_loss: 41.3860 - val_mean_absolute_error: 5.3258
# Epoch 29/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4442 - mean_absolute_error: 1.7148 - val_loss: 31.6466 - val_mean_absolute_error: 4.4815
# Epoch 30/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7539 - mean_absolute_error: 2.1267 - val_loss: 35.3618 - val_mean_absolute_error: 4.8982
# Epoch 31/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4625 - mean_absolute_error: 1.7282 - val_loss: 35.4336 - val_mean_absolute_error: 4.8998
# Epoch 32/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2739 - mean_absolute_error: 1.6821 - val_loss: 38.4569 - val_mean_absolute_error: 5.1206
# Epoch 33/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2369 - mean_absolute_error: 1.8110 - val_loss: 33.5291 - val_mean_absolute_error: 4.7312
# Epoch 34/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7898 - mean_absolute_error: 1.8002 - val_loss: 34.2608 - val_mean_absolute_error: 4.8019
# Epoch 35/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4834 - mean_absolute_error: 1.7570 - val_loss: 31.5280 - val_mean_absolute_error: 4.5347
# Epoch 36/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0525 - mean_absolute_error: 1.6942 - val_loss: 38.2366 - val_mean_absolute_error: 5.0970
# Epoch 37/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2653 - mean_absolute_error: 1.6771 - val_loss: 37.5794 - val_mean_absolute_error: 5.0485
# Epoch 38/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2686 - mean_absolute_error: 1.6998 - val_loss: 37.8521 - val_mean_absolute_error: 5.0512
# Epoch 39/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8897 - mean_absolute_error: 1.7262 - val_loss: 35.2965 - val_mean_absolute_error: 4.8784
# Epoch 40/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3405 - mean_absolute_error: 1.6997 - val_loss: 36.0669 - val_mean_absolute_error: 4.9445
# Epoch 41/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2849 - mean_absolute_error: 1.6505 - val_loss: 33.5843 - val_mean_absolute_error: 4.7482
# Epoch 42/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4941 - mean_absolute_error: 1.8491 - val_loss: 38.5088 - val_mean_absolute_error: 5.1137
# Epoch 43/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3708 - mean_absolute_error: 1.6642 - val_loss: 36.0235 - val_mean_absolute_error: 4.9257
# Epoch 44/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3764 - mean_absolute_error: 1.6974 - val_loss: 41.0985 - val_mean_absolute_error: 5.2987
# Epoch 45/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7871 - mean_absolute_error: 1.7785 - val_loss: 36.6153 - val_mean_absolute_error: 4.9650
# Epoch 46/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4320 - mean_absolute_error: 1.8336 - val_loss: 33.8241 - val_mean_absolute_error: 4.7636
# Epoch 47/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6367 - mean_absolute_error: 1.5790 - val_loss: 35.9905 - val_mean_absolute_error: 4.9163
# Epoch 48/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3022 - mean_absolute_error: 1.6870 - val_loss: 29.4478 - val_mean_absolute_error: 4.3381
# Epoch 49/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5266 - mean_absolute_error: 1.8472 - val_loss: 34.7845 - val_mean_absolute_error: 4.8357
# Epoch 50/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6118 - mean_absolute_error: 1.7372 - val_loss: 40.1212 - val_mean_absolute_error: 5.2327
# Epoch 51/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.8784 - mean_absolute_error: 1.6677 - val_loss: 30.8223 - val_mean_absolute_error: 4.5150
# Epoch 52/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1607 - mean_absolute_error: 1.7141 - val_loss: 38.2060 - val_mean_absolute_error: 5.0978
# Epoch 53/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5228 - mean_absolute_error: 1.7449 - val_loss: 30.0910 - val_mean_absolute_error: 4.4112
# Epoch 54/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2903 - mean_absolute_error: 1.7358 - val_loss: 36.9255 - val_mean_absolute_error: 4.9909
# Epoch 55/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1231 - mean_absolute_error: 1.6696 - val_loss: 41.3847 - val_mean_absolute_error: 5.3224
# Epoch 56/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6185 - mean_absolute_error: 1.6424 - val_loss: 36.6763 - val_mean_absolute_error: 4.9725
# Epoch 57/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4623 - mean_absolute_error: 1.6893 - val_loss: 35.8171 - val_mean_absolute_error: 4.9278
# Epoch 58/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2502 - mean_absolute_error: 1.8384 - val_loss: 38.6867 - val_mean_absolute_error: 5.1152
# Epoch 59/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3252 - mean_absolute_error: 1.7040 - val_loss: 35.0199 - val_mean_absolute_error: 4.8504
# Epoch 60/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9905 - mean_absolute_error: 1.6169 - val_loss: 33.5824 - val_mean_absolute_error: 4.7421
# Epoch 61/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6700 - mean_absolute_error: 1.7870 - val_loss: 29.4838 - val_mean_absolute_error: 4.3582
# Epoch 62/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5864 - mean_absolute_error: 1.7630 - val_loss: 29.9135 - val_mean_absolute_error: 4.3866
# Epoch 63/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6260 - mean_absolute_error: 1.7278 - val_loss: 33.1955 - val_mean_absolute_error: 4.7006
# Epoch 64/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2285 - mean_absolute_error: 1.6976 - val_loss: 36.5545 - val_mean_absolute_error: 4.9603
# Epoch 65/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2320 - mean_absolute_error: 1.6936 - val_loss: 35.1467 - val_mean_absolute_error: 4.8444
# Epoch 66/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5459 - mean_absolute_error: 1.7186 - val_loss: 31.5397 - val_mean_absolute_error: 4.5489
# Epoch 67/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8893 - mean_absolute_error: 1.8780 - val_loss: 36.3092 - val_mean_absolute_error: 4.9261
# Epoch 68/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9447 - mean_absolute_error: 1.6221 - val_loss: 32.5570 - val_mean_absolute_error: 4.6422
# Epoch 69/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1908 - mean_absolute_error: 1.6657 - val_loss: 34.3032 - val_mean_absolute_error: 4.7806
# Epoch 70/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7781 - mean_absolute_error: 1.8503 - val_loss: 40.1264 - val_mean_absolute_error: 5.2074
# Epoch 71/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9689 - mean_absolute_error: 1.9267 - val_loss: 36.8151 - val_mean_absolute_error: 4.9795
# Epoch 72/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0731 - mean_absolute_error: 1.7825 - val_loss: 39.4376 - val_mean_absolute_error: 5.1793
# Epoch 73/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5075 - mean_absolute_error: 1.7220 - val_loss: 36.4476 - val_mean_absolute_error: 4.9484
# Epoch 74/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1469 - mean_absolute_error: 1.7826 - val_loss: 32.8030 - val_mean_absolute_error: 4.6725
# Epoch 75/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8880 - mean_absolute_error: 1.6200 - val_loss: 31.3863 - val_mean_absolute_error: 4.5468
# Epoch 76/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1025 - mean_absolute_error: 1.6816 - val_loss: 31.9312 - val_mean_absolute_error: 4.5975
# Epoch 77/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9962 - mean_absolute_error: 1.6574 - val_loss: 26.3357 - val_mean_absolute_error: 4.0602
# Epoch 78/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6746 - mean_absolute_error: 1.7683 - val_loss: 33.4831 - val_mean_absolute_error: 4.7067
# Epoch 79/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9043 - mean_absolute_error: 1.7901 - val_loss: 39.4434 - val_mean_absolute_error: 5.1554
# Epoch 80/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8941 - mean_absolute_error: 1.7333 - val_loss: 33.4907 - val_mean_absolute_error: 4.7290
# Epoch 81/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1418 - mean_absolute_error: 1.6346 - val_loss: 37.2697 - val_mean_absolute_error: 5.0096
# Epoch 82/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1359 - mean_absolute_error: 1.6621 - val_loss: 40.6623 - val_mean_absolute_error: 5.2580
# Epoch 83/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8052 - mean_absolute_error: 1.7501 - val_loss: 34.9426 - val_mean_absolute_error: 4.8436
# Epoch 84/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5452 - mean_absolute_error: 1.7577 - val_loss: 31.0629 - val_mean_absolute_error: 4.5201
# Epoch 85/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8393 - mean_absolute_error: 1.7260 - val_loss: 35.3420 - val_mean_absolute_error: 4.8847
# Epoch 86/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7768 - mean_absolute_error: 1.9330 - val_loss: 30.4402 - val_mean_absolute_error: 4.4316
# Epoch 87/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5912 - mean_absolute_error: 1.8196 - val_loss: 35.8778 - val_mean_absolute_error: 4.9123
# Epoch 88/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6312 - mean_absolute_error: 1.8230 - val_loss: 37.1613 - val_mean_absolute_error: 4.9982
# Epoch 89/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4553 - mean_absolute_error: 1.6998 - val_loss: 38.5273 - val_mean_absolute_error: 5.1160
# Epoch 90/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2831 - mean_absolute_error: 1.7923 - val_loss: 29.4090 - val_mean_absolute_error: 4.3412
# Epoch 91/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0953 - mean_absolute_error: 1.8810 - val_loss: 39.8117 - val_mean_absolute_error: 5.2008
# Epoch 92/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9767 - mean_absolute_error: 1.8162 - val_loss: 30.3909 - val_mean_absolute_error: 4.4458
# Epoch 93/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.5954 - mean_absolute_error: 1.7520 - val_loss: 45.8847 - val_mean_absolute_error: 5.6018
# Epoch 94/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2284 - mean_absolute_error: 1.6573 - val_loss: 35.6351 - val_mean_absolute_error: 4.8756
# Epoch 95/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9545 - mean_absolute_error: 1.7381 - val_loss: 31.8624 - val_mean_absolute_error: 4.5728
# Epoch 96/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2793 - mean_absolute_error: 1.8758 - val_loss: 33.1351 - val_mean_absolute_error: 4.6875
# Epoch 97/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4620 - mean_absolute_error: 1.6847 - val_loss: 33.2983 - val_mean_absolute_error: 4.7249
# Epoch 98/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1569 - mean_absolute_error: 1.7076 - val_loss: 35.1303 - val_mean_absolute_error: 4.8435
# Epoch 99/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8073 - mean_absolute_error: 1.7046 - val_loss: 33.4997 - val_mean_absolute_error: 4.7414
# Epoch 100/100
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2171 - mean_absolute_error: 1.7202 - val_loss: 33.2853 - val_mean_absolute_error: 4.7057

# %%
train_predictions = model.predict(X_train).flatten()
plt. plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
val_predictions = model.predict(X_val).flatten()
plt. plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %% [markdown]
# LSTM Can't extrapolate data well. (Extrapolate means predict data out of the time zone or outside your field of knowledge, create prediction) The LSTM Is only good at data it is familiar with.

# %%
import datetime
import matplotlib.dates as mdates

def predict_next_month(model, last_n_days, num_days=15):
    """
    Predicts the stock price for the next month, day by day.

    Args:
        model: The trained LSTM model.
        last_n_days: The last 'n' days of data used for the initial prediction.
        num_days: The number of days to predict (default: 30).

    Returns:
        A tuple containing the predicted dates and prices.
    """

    predictions = []
    current_date = dates_test[-1] + datetime.timedelta(days=1)  # Start from the day after the last test date
    input_data = last_n_days.reshape(1, last_n_days.shape[0], 1)  # Reshape for model input

    for _ in range(num_days):
        prediction = model.predict(input_data)[0, 0]  # Predict next day's price
        predictions.append(prediction)

        # Update input data with the prediction for the next iteration
        input_data = np.roll(input_data, -1, axis=1)  # Shift data one day back
        input_data[0, -1, 0] = prediction  # Replace last value with prediction

        current_date += datetime.timedelta(days=1)

    predicted_dates = [dates_test[-1] + datetime.timedelta(days=i + 1) for i in range(num_days)]

    return predicted_dates, predictions

# Get the last 15 days of data from the test set
last_15_days = X_test[-1, :, 0]

# Predict for the next 30 days
predicted_dates, predicted_prices = predict_next_month(model, last_15_days)

# Plot the predicted data
plt.plot(predicted_dates, predicted_prices, label='Predicted')
plt.xlabel('Date')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d'))
plt.ylabel('Stock Price')
plt.title('Next 15 days Prediction')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
test_predictions = []
input_data = X_test[0, :, 0]  # Start with the first 15 days of the test set

for i in range(len(dates_test)):
  # Reshape for model input
  input_data_reshaped = input_data.reshape(1, input_data.shape[0], 1)

  # Predict
  prediction = model.predict(input_data_reshaped)[0, 0]
  test_predictions.append(prediction)

  # Update input data
  input_data = np.roll(input_data, -1)  # Shift one step back
  input_data[-1] = prediction  # Replace last value with prediction

# Convert to NumPy array for plotting
test_predictions = np.array(test_predictions)

# Plot
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
test_predictions = []
input_data = X_test[0, :, 0]  # Start with the first 15 days of the test set

# Observation Phase (First 15 Days)
for i in range(15): #for the first 15 days
  input_data_reshaped = input_data.reshape(1, input_data.shape[0], 1)
  prediction = model.predict(input_data_reshaped)[0, 0]
  test_predictions.append(prediction)

  # Update with actual observation
  input_data = np.roll(input_data, -1)
  input_data[-1] = y_test[i]

# Prediction Phase (Next 15 Days)
for i in range(15, len(dates_test)):  # Start from day 16
  input_data_reshaped = input_data.reshape(1, input_data.shape[0], 1)
  prediction = model.predict(input_data_reshaped)[0, 0]
  test_predictions.append(prediction)

  # Update with prediction
  input_data = np.roll(input_data, -1)
  input_data[-1] = prediction

# Convert to NumPy array for plotting
test_predictions = np.array(test_predictions)

# Plot
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
